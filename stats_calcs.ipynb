# %%
import pickle
import pandas as pd
from unidecode import unidecode
import numpy as np
import scipy.io
from scipy.optimize import minimize
from scipy.stats import norm
import matplotlib.pyplot as plt
import os

ficheros_total = []


PATH_UPV = "./DatosExperimento1/UPV"
PATH_VARIABLES = "./variables"

# Leer el archivo Excel en un DataFrame de pandas
df = pd.read_excel(PATH_UPV+'/Exp1_Observadores_UPV.xlsx')
    
if not os.path.exists('Resultados_UPV'):
    os.makedirs('Resultados_UPV')

# Crear un diccionario vacío para almacenar los resultados
voluntarios_upv = {}

# Iterar sobre cada fila del DataFrame
for idx, row in df.iterrows():
    # Tratamiento de nombre y apellidos para evitar que una misma persona se trate como diferente:
    # Quito espacios, mayusculas, minuscula s, etc
    nombre = unidecode(row['Nombre'].lower())
    apellidos = unidecode(row['Apellidos'].split(" ")[0].lower())
    fichero = row['Fichero']
    # Crear la clave del diccionario usando el nombre y apellidos
    clave = f"{nombre}-{apellidos}".replace(" ", "")
    
    # Agregar el valor de la columna "Fichero" a la lista correspondiente en el diccionario
    if clave in voluntarios_upv:
        voluntarios_upv[clave].append(fichero)
    else:
        voluntarios_upv[clave] = [fichero]
        
    ficheros_total.append(PATH_UPV+"/"+row['Fichero'])

voluntarios_upv
# Out:
# {'voluntario_upv_1-_1': ['ResultsJNDsNoiseFlatBG20211129T112353.mat',
#   'ResultsJNDsNoiseFlatBG20211129T120005.mat'],
#  'voluntario_upv_2-_2': ['ResultsJNDsNoiseFlatBG20211129T133717.mat',
#   'ResultsJNDsNoiseFlatBG20211129T140322.mat'],
#  'voluntario_upv_3-_3': ['ResultsJNDsNoiseFlatBG20211129T163621.mat',
#   'ResultsJNDsNoiseFlatBG20211129T171934.mat'],
#  'voluntario_upv_4-_4': ['ResultsJNDsNoiseFlatBG20211130T105700.mat',
#   'ResultsJNDsNoiseFlatBG20220111T121738.mat'],
#  'voluntario_upv_5-_5': ['ResultsJNDsNoiseFlatBG20211201T114113.mat',
#   'ResultsJNDsNoiseFlatBG20211210T120626.mat'],
#  'voluntario_upv_6-_6': ['ResultsJNDsNoiseFlatBG20211202T140213.mat',
#   'ResultsJNDsNoiseFlatBG20211202T142641.mat'],
#  'voluntario_upv_7-_7': ['ResultsJNDsNoiseFlatBG20211203T102719.mat',
#   'ResultsJNDsNoiseFlatBG20220124T090423.mat'],
#  'voluntario_upv_8-_8': ['ResultsJNDsNoiseFlatBG20211210T101730.mat',
#   'ResultsJNDsNoiseFlatBG20211210T112932.mat'],
#  'voluntario_upv_9-_9': ['ResultsJNDsNoiseFlatBG20211210T105955.mat',
#   'ResultsJNDsNoiseFlatBG20220127T121914.mat'],
#  'voluntario_upv_11-_11': ['ResultsJNDsNoiseFlatBG20211210T145230.mat',
#   'ResultsJNDsNoiseFlatBG20220124T123446.mat'],
#  'voluntario_upv_12-_12': ['ResultsJNDsNoiseFlatBG20211210T160923.mat',
#   'ResultsJNDsNoiseFlatBG20211210T163932.mat'],
#  'voluntario_upv_13-_13': ['ResultsJNDsNoiseFlatBG20211217T141916.mat',
#   'ResultsJNDsNoiseFlatBG20211222T112032.mat'],
#  'voluntario_upv_14-_14': ['ResultsJNDsNoiseFlatBG20211217T171615.mat',
#   'ResultsJNDsNoiseFlatBG20211220T112329.mat'],
#  'voluntario_upv_16-_16': ['ResultsJNDsNoiseFlatBG20220111T140857.mat',
#   'ResultsJNDsNoiseFlatBG20220113T142427.mat'],
#  'voluntario_upv_17-_17': ['ResultsJNDsNoiseFlatBG20220117T125215.mat',
#   'ResultsJNDsNoiseFlatBG20220117T131752.mat'],
#  'voluntario_upv_18-_18': ['ResultsJNDsNoiseFlatBG20220117T161356.mat'],
#  'voluntario_upv_19-_19': ['ResultsJNDsNoiseFlatBG20220118T094314.mat',
#   'ResultsJNDsNoiseFlatBG20220118T100419.mat'],
#  'voluntario_upv_20-_20': ['ResultsJNDsNoiseFlatBG20220118T104104.mat',
#   'ResultsJNDsNoiseFlatBG20220118T110520.mat'],
#  'voluntario_upv_21-_21': ['ResultsJNDsNoiseFlatBG20220120T182621.mat',
#   'ResultsJNDsNoiseFlatBG20220120T185212.mat'],
#  'voluntario_upv_22-_22': ['ResultsJNDsNoiseFlatBG20220121T112005.mat',
#   'ResultsJNDsNoiseFlatBG20220121T114403.mat'],
#  'voluntario_upv_23-_23': ['ResultsJNDsNoiseFlatBG20220121T122915.mat',
#   'ResultsJNDsNoiseFlatBG20220121T130458.mat'],
#  'voluntario_upv_26-_26': ['ResultsJNDsNoiseFlatBG20220125T111912.mat',
#   'ResultsJNDsNoiseFlatBG20220125T114644.mat'],
#  'voluntario_upv_28-_28': ['ResultsJNDsNoiseFlatBG20220127T124659.mat',
#   'ResultsJNDsNoiseFlatBG20220128T123931.mat'],
#  'voluntario_upv_29-_29': ['ResultsJNDsNoiseFlatBG20220127T133215.mat',
#   'ResultsJNDsNoiseFlatBG20220131T132610.mat'],
#  'voluntario_upv_30-_30': ['ResultsJNDsNoiseFlatBG20220131T144132.mat'],
#  'voluntario_upv_31-_31': ['ResultsJNDsNoiseFlatBG20220202T131819.mat',
#   'ResultsJNDsNoiseFlatBG20220202T143731.mat'],
#  'voluntario_upv_32-_32': ['ResultsJNDsNoiseFlatBG20220202T133856.mat',
#   'ResultsJNDsNoiseFlatBG20220202T145451.mat'],
#  'voluntario_upv_33-_33': ['ResultsJNDsNoiseFlatBG20220202T135933.mat',
#   'ResultsJNDsNoiseFlatBG20220202T151326.mat'],
#  'voluntario_upv_34-_34': ['ResultsJNDsNoiseFlatBG20220203T123900.mat',
#   'ResultsJNDsNoiseFlatBG20220204T113646.mat'],
#  'voluntario_upv_35-_35': ['ResultsJNDsNoiseFlatBG20220204T105347.mat',
#   'ResultsJNDsNoiseFlatBG20220210T105658.mat'],
#  'voluntario_upv_36-_36': ['ResultsJNDsNoiseFlatBG20220204T122529.mat',
#   'ResultsJNDsNoiseFlatBG20220204T122529.mat']}

# %%
stats_upv = {}
# Diccionario donde se almacenará para cada usuario sus caracterísitcas: nombre, apellidos, edad, género, experiencia, universidad y el fichero/s donde se encuentran sus experiementos.

for voluntario, ficheros in voluntarios_upv.items():   
    edad = None
    genero = None
    experto = None
    for fichero in ficheros:
        data_file = PATH_UPV+'/'+fichero
        data = scipy.io.loadmat(data_file)
        datos = np.array(data['datos'])[0]
        nombre = datos[0][0][0]
        apellidos = datos[0][1][0]
        
        if edad is None:
            edad = datos[0][2][0][0]
        elif edad != datos[0][2][0][0]:
            print(f"EDAD DISTINTA PARA MISMO USUARIO {edad} != {datos[0][2][0][0]}. Usuario {voluntario}")
            edad = max([edad, datos[0][2][0][0]])
            
        if genero is None:
            genero = datos[0][3][0][0]
        elif genero != datos[0][3][0][0]:
            print(f"GENERO DISTINTO PARA MISMO USUARIO {genero} != {datos[0][3][0][0]}. Usuario {voluntario}")
            
        if experto is None:
            experto = bool(datos[0][4][0][0])
        elif experto != bool(datos[0][4][0][0]):
            print(f"EXPERTO DISTINO PARA MISMO USUARIO {experto} != {bool(datos[0][4][0][0])}. Usuario {voluntario}")
            experto = True
    
    stats_upv[voluntario] = {}            
    stats_upv[voluntario]["nombre"] = nombre
    stats_upv[voluntario]["apellidos"] = apellidos
    stats_upv[voluntario]["edad"] = edad
    stats_upv[voluntario]["genero"] = genero
    stats_upv[voluntario]["experto"] = experto
    stats_upv[voluntario]["data_files"] = ficheros
    stats_upv[voluntario]["universidad"] = "UPV"
        
stats_upv
# Out:
# EDAD DISTINTA PARA MISMO USUARIO 63 != 1. Usuario voluntario_upv_4-_4
# EDAD DISTINTA PARA MISMO USUARIO 56 != 57. Usuario voluntario_upv_7-_7
# EXPERTO DISTINO PARA MISMO USUARIO True != False. Usuario voluntario_upv_7-_7
# EDAD DISTINTA PARA MISMO USUARIO 33 != 34. Usuario voluntario_upv_11-_11
# {'voluntario_upv_1-_1': {'nombre': 'voluntario_upv_1',
#   'apellidos': '_1       ',
#   'edad': 31,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211129T112353.mat',
#    'ResultsJNDsNoiseFlatBG20211129T120005.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_2-_2': {'nombre': 'voluntario_upv_2',
#   'apellidos': '_2   ',
#   'edad': 60,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211129T133717.mat',
#    'ResultsJNDsNoiseFlatBG20211129T140322.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_3-_3': {'nombre': 'voluntario_upv_3',
#   'apellidos': '_3  ',
#   'edad': 49,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211129T163621.mat',
#    'ResultsJNDsNoiseFlatBG20211129T171934.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_4-_4': {'nombre': 'voluntario_upv_4',
#   'apellidos': '_4    ',
#   'edad': 63,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211130T105700.mat',
#    'ResultsJNDsNoiseFlatBG20220111T121738.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_5-_5': {'nombre': 'voluntario_upv_5',
#   'apellidos': '_5     ',
#   'edad': 35,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211201T114113.mat',
#    'ResultsJNDsNoiseFlatBG20211210T120626.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_6-_6': {'nombre': 'voluntario_upv_6',
#   'apellidos': '_6              ',
#   'edad': 45,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211202T140213.mat',
#    'ResultsJNDsNoiseFlatBG20211202T142641.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_7-_7': {'nombre': 'voluntario_upv_7',
#   'apellidos': '_7               ',
#   'edad': 57,
#   'genero': 'M',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211203T102719.mat',
#    'ResultsJNDsNoiseFlatBG20220124T090423.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_8-_8': {'nombre': 'voluntario_upv_8',
#   'apellidos': '_8              ',
#   'edad': 41,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211210T101730.mat',
#    'ResultsJNDsNoiseFlatBG20211210T112932.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_9-_9': {'nombre': 'voluntario_upv_9',
#   'apellidos': '_9     ',
#   'edad': 57,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211210T105955.mat',
#    'ResultsJNDsNoiseFlatBG20220127T121914.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_11-_11': {'nombre': 'voluntario_upv_11',
#   'apellidos': '_11    ',
#   'edad': 34,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211210T145230.mat',
#    'ResultsJNDsNoiseFlatBG20220124T123446.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_12-_12': {'nombre': 'voluntario_upv_12',
#   'apellidos': '_12     ',
#   'edad': 51,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211210T160923.mat',
#    'ResultsJNDsNoiseFlatBG20211210T163932.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_13-_13': {'nombre': 'voluntario_upv_13',
#   'apellidos': '_13    ',
#   'edad': 51,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211217T141916.mat',
#    'ResultsJNDsNoiseFlatBG20211222T112032.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_14-_14': {'nombre': 'voluntario_upv_14',
#   'apellidos': '_14   ',
#   'edad': 21,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211217T171615.mat',
#    'ResultsJNDsNoiseFlatBG20211220T112329.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_16-_16': {'nombre': 'voluntario_upv_16',
#   'apellidos': '_16       ',
#   'edad': 37,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220111T140857.mat',
#    'ResultsJNDsNoiseFlatBG20220113T142427.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_17-_17': {'nombre': 'voluntario_upv_17',
#   'apellidos': '_17     ',
#   'edad': 57,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220117T125215.mat',
#    'ResultsJNDsNoiseFlatBG20220117T131752.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_18-_18': {'nombre': 'voluntario_upv_18',
#   'apellidos': '_18    ',
#   'edad': 31,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220117T161356.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_19-_19': {'nombre': 'voluntario_upv_19',
#   'apellidos': '_19       ',
#   'edad': 38,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220118T094314.mat',
#    'ResultsJNDsNoiseFlatBG20220118T100419.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_20-_20': {'nombre': 'voluntario_upv_20',
#   'apellidos': '_20           ',
#   'edad': 21,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220118T104104.mat',
#    'ResultsJNDsNoiseFlatBG20220118T110520.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_21-_21': {'nombre': 'voluntario_upv_21',
#   'apellidos': '_21            ',
#   'edad': 41,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220120T182621.mat',
#    'ResultsJNDsNoiseFlatBG20220120T185212.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_22-_22': {'nombre': 'voluntario_upv_22',
#   'apellidos': '_22            ',
#   'edad': 21,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220121T112005.mat',
#    'ResultsJNDsNoiseFlatBG20220121T114403.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_23-_23': {'nombre': 'voluntario_upv_23',
#   'apellidos': '_23           ',
#   'edad': 22,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220121T122915.mat',
#    'ResultsJNDsNoiseFlatBG20220121T130458.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_26-_26': {'nombre': 'voluntario_upv_26',
#   'apellidos': '_26            ',
#   'edad': 21,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220125T111912.mat',
#    'ResultsJNDsNoiseFlatBG20220125T114644.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_28-_28': {'nombre': 'voluntario_upv_28',
#   'apellidos': '_28            ',
#   'edad': 27,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220127T124659.mat',
#    'ResultsJNDsNoiseFlatBG20220128T123931.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_29-_29': {'nombre': 'voluntario_upv_29',
#   'apellidos': '_29               ',
#   'edad': 41,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220127T133215.mat',
#    'ResultsJNDsNoiseFlatBG20220131T132610.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_30-_30': {'nombre': 'voluntario_upv_30',
#   'apellidos': '_30         ',
#   'edad': 18,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220131T144132.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_31-_31': {'nombre': 'voluntario_upv_31',
#   'apellidos': '_31            ',
#   'edad': 19,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220202T131819.mat',
#    'ResultsJNDsNoiseFlatBG20220202T143731.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_32-_32': {'nombre': 'voluntario_upv_32',
#   'apellidos': '_32             ',
#   'edad': 19,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220202T133856.mat',
#    'ResultsJNDsNoiseFlatBG20220202T145451.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_33-_33': {'nombre': 'voluntario_upv_33',
#   'apellidos': '_33               ',
#   'edad': 19,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220202T135933.mat',
#    'ResultsJNDsNoiseFlatBG20220202T151326.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_34-_34': {'nombre': 'voluntario_upv_34',
#   'apellidos': '_34       ',
#   'edad': 20,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220203T123900.mat',
#    'ResultsJNDsNoiseFlatBG20220204T113646.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_35-_35': {'nombre': 'voluntario_upv_35',
#   'apellidos': '_35       ',
#   'edad': 54,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220204T105347.mat',
#    'ResultsJNDsNoiseFlatBG20220210T105658.mat'],
#   'universidad': 'UPV'},
#  'voluntario_upv_36-_36': {'nombre': 'voluntario_upv_36',
#   'apellidos': '_36   ',
#   'edad': 18,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220204T122529.mat',
#    'ResultsJNDsNoiseFlatBG20220204T122529.mat'],
#   'universidad': 'UPV'}}

# %%
import matplotlib.pyplot as plt


edades = [datos['edad'] for datos in stats_upv.values()]
plt.hist(edades, bins=10, edgecolor='black')
plt.title('Histograma de Edades para UPV')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()


generos = [datos['genero'] for datos in stats_upv.values()]
plt.hist(generos, bins=2, edgecolor='black')
plt.title('Histograma de Género para UPV')
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()


expertos = np.array([datos['experto'] for datos in stats_upv.values()], dtype=np.uint8)
plt.hist(expertos, bins=2, edgecolor='black')
plt.title('Histograma de Experto para UPV')
plt.xlabel('Experto')
plt.ylabel('Frecuencia')
plt.xticks([0, 1], ['No', 'Sí'])
plt.show()

# %%
PATH_UGR = "./DatosExperimento1/UGR"

# Leer el archivo Excel en un DataFrame de pandas
df_ugr = pd.read_excel(PATH_UGR+'/Exp1_Observadores_UGR.xlsx')
    
if not os.path.exists('Resultados_UGR'):
    os.makedirs('Resultados_UGR')

# Crear un diccionario vacío para almacenar los resultados
voluntarios_ugr = {}

# Iterar sobre cada fila del DataFrame
for idx, row in df_ugr.iterrows():
    # Tratamiento de nombre y apellidos para evitar que una misma persona se trate como diferente:
    # Quito espacios, mayusculas, minuscula s, etc
    nombre = unidecode(row['Nombre'].lower())
    apellidos = unidecode(row['Apellidos'].split(" ")[0].lower())
    fichero = row['Fichero']
    # Crear la clave del diccionario usando el nombre y apellidos
    clave = f"{nombre}-{apellidos}".replace(" ", "")
    
    # Agregar el valor de la columna "Fichero" a la lista correspondiente en el diccionario
    if clave in voluntarios_ugr:
        voluntarios_ugr[clave].append(fichero)
    else:
        voluntarios_ugr[clave] = [fichero]

    ficheros_total.append(PATH_UGR+"/"+row['Fichero'])

voluntarios_ugr
# Out:
# {'voluntario_ugr_1-_1': ['ResultsJNDsNoiseFlatBG20220401T131441.mat'],
#  'voluntario_ugr_2-_2': ['ResultsJNDsNoiseFlatBG20220317T113653.mat',
#   'ResultsJNDsNoiseFlatBG20220407T113228.mat'],
#  'voluntario_ugr_3-_3': ['ResultsJNDsNoiseFlatBG20220201T134054.mat',
#   'ResultsJNDsNoiseFlatBG20220202T124958.mat'],
#  'voluntario_ugr_4-_4': ['ResultsJNDsNoiseFlatBG20220427T114635.mat',
#   'ResultsJNDsNoiseFlatBG20220408T103353.mat'],
#  'voluntario_ugr_5-_5': ['ResultsJNDsNoiseFlatBG20220401T121203.mat',
#   'ResultsJNDsNoiseFlatBG20220323T132705.mat'],
#  'voluntario_ugr_6-_6': ['ResultsJNDsNoiseFlatBG20220303T125835.mat',
#   'ResultsJNDsNoiseFlatBG20220314T113216.mat'],
#  'voluntario_ugr_7-_7': ['ResultsJNDsNoiseFlatBG20220318T133520.mat'],
#  'voluntario_ugr_8-_8': ['ResultsJNDsNoiseFlatBG20220411T193944.mat',
#   'ResultsJNDsNoiseFlatBG20220420T172846.mat'],
#  'voluntario_ugr_9-_9': ['ResultsJNDsNoiseFlatBG20220223T112641.mat',
#   'ResultsJNDsNoiseFlatBG20220223T161544.mat'],
#  'voluntario_ugr_10-_10': ['ResultsJNDsNoiseFlatBG20220209T132743.mat',
#   'ResultsJNDsNoiseFlatBG20220204T134543.mat'],
#  'voluntario_ugr_11-_11': ['ResultsJNDsNoiseFlatBG20220202T113037.mat',
#   'ResultsJNDsNoiseFlatBG20220208T122326.mat'],
#  'voluntario_ugr_12-_12': ['ResultsJNDsNoiseFlatBG20220204T112945.mat',
#   'ResultsJNDsNoiseFlatBG20220426T124527.mat'],
#  'voluntario_ugr_13-_13': ['ResultsJNDsNoiseFlatBG20220121T133331.mat',
#   'ResultsJNDsNoiseFlatBG20220204T123031.mat'],
#  'voluntario_ugr_14-_14': ['ResultsJNDsNoiseFlatBG20220114T110151.mat',
#   'ResultsJNDsNoiseFlatBG20220121T104058.mat'],
#  'voluntario_ugr_15-_15': ['ResultsJNDsNoiseFlatBG20220406T123850.mat',
#   'ResultsJNDsNoiseFlatBG20220421T122349.mat'],
#  'voluntario_ugr_16-_16': ['ResultsJNDsNoiseFlatBG20211217T115223.mat',
#   'ResultsJNDsNoiseFlatBG20220114T114049.mat'],
#  'voluntario_ugr_17-_17': ['ResultsJNDsNoiseFlatBG20220411T201459.mat',
#   'ResultsJNDsNoiseFlatBG20220421T180502.mat'],
#  'voluntario_ugr_18-_18': ['ResultsJNDsNoiseFlatBG20220422T111834.mat',
#   'ResultsJNDsNoiseFlatBG20220426T093703.mat',
#   'ResultsJNDsNoiseFlatBG20220405T100824.mat'],
#  'voluntario_ugr_19-_19': ['ResultsJNDsNoiseFlatBG20220331T123440.mat',
#   'ResultsJNDsNoiseFlatBG20220419T122341.mat'],
#  'voluntario_ugr_20-_20': ['ResultsJNDsNoiseFlatBG20220302T112937.mat',
#   'ResultsJNDsNoiseFlatBG20220304T105123.mat'],
#  'voluntario_ugr_21-_21': ['ResultsJNDsNoiseFlatBG20220114T120209.mat',
#   'ResultsJNDsNoiseFlatBG20220128T092751.mat'],
#  'voluntario_ugr_22-_22': ['ResultsJNDsNoiseFlatBG20220328T140217.mat',
#   'ResultsJNDsNoiseFlatBG20220330T140514.mat'],
#  'voluntario_ugr_23-_23': ['ResultsJNDsNoiseFlatBG20220127T145837.mat',
#   'ResultsJNDsNoiseFlatBG20220121T122318.mat'],
#  'voluntario_ugr_24-_24': ['ResultsJNDsNoiseFlatBG20220202T174903.mat',
#   'ResultsJNDsNoiseFlatBG20220207T134041.mat'],
#  'voluntario_ugr_25-_25': ['ResultsJNDsNoiseFlatBG20220121T112811.mat',
#   'ResultsJNDsNoiseFlatBG20220127T141004.mat'],
#  'voluntario_ugr_26-_26': ['ResultsJNDsNoiseFlatBG20220425T172713.mat',
#   'ResultsJNDsNoiseFlatBG20220422T124814.mat'],
#  'voluntario_ugr_27-_27': ['ResultsJNDsNoiseFlatBG20220201T111133.mat',
#   'ResultsJNDsNoiseFlatBG20220202T134220.mat'],
#  'voluntario_ugr_28-_28': ['ResultsJNDsNoiseFlatBG20220405T132104.mat',
#   'ResultsJNDsNoiseFlatBG20220401T134721.mat'],
#  'voluntario_ugr_29-_29': ['ResultsJNDsNoiseFlatBG20220216T114246.mat',
#   'ResultsJNDsNoiseFlatBG20220223T104302.mat',
#   'ResultsJNDsNoiseFlatBG20220301T101810.mat'],
#  'voluntario_ugr_30-_30': ['ResultsJNDsNoiseFlatBG20220317T132259.mat',
#   'ResultsJNDsNoiseFlatBG20220407T125413.mat'],
#  'voluntario_ugr_31-_31': ['ResultsJNDsNoiseFlatBG20220420T175405.mat',
#   'ResultsJNDsNoiseFlatBG20220427T184121.mat'],
#  'voluntario_ugr_32-_32': ['ResultsJNDsNoiseFlatBG20220114T124227.mat',
#   'ResultsJNDsNoiseFlatBG20220202T105219.mat'],
#  'voluntario_ugr_33-_33': ['ResultsJNDsNoiseFlatBG20220211T125927.mat',
#   'ResultsJNDsNoiseFlatBG20220405T122450.mat'],
#  'voluntario_ugr_34-_34': ['ResultsJNDsNoiseFlatBG20220114T122007.mat',
#   'ResultsJNDsNoiseFlatBG20220128T130104.mat'],
#  'voluntario_ugr_35-_35': ['ResultsJNDsNoiseFlatBG20220308T111929.mat',
#   'ResultsJNDsNoiseFlatBG20220209T104348.mat'],
#  'voluntario_ugr_36-_36': ['ResultsJNDsNoiseFlatBG20220428T132532.mat'],
#  'voluntario_ugr_37-_37': ['ResultsJNDsNoiseFlatBG20220407T102908.mat',
#   'ResultsJNDsNoiseFlatBG20220317T095724.mat']}

# %%
stats_ugr = {}
# Diccionario donde se almacenará para cada usuario sus caracterísitcas: nombre, apellidos, edad, género, experiencia, universidad y el fichero/s donde se encuentran sus experiementos.

for voluntario, ficheros in voluntarios_ugr.items():
    edad = None
    genero = None
    experto = None
    for fichero in ficheros:
        data_file = PATH_UGR+'/'+fichero
        data = scipy.io.loadmat(data_file)
        datos = np.array(data['datos'])[0]
        nombre = datos[0][0][0]
        apellidos = datos[0][1][0]
        
        if edad is None:
            edad = datos[0][2][0][0]
        elif edad != datos[0][2][0][0]:
            print(f"EDAD DISTINTA PARA MISMO USUARIO {edad} != {datos[0][2][0][0]}. Usuario {voluntario}")
            edad = max([edad, datos[0][2][0][0]])
            
        if genero is None:
            genero = datos[0][3][0][0]
        elif genero != datos[0][3][0][0]:
            print(f"GENERO DISTINTO PARA MISMO USUARIO {genero} != {datos[0][3][0][0]}. Usuario {voluntario}")
            
        if experto is None:
            experto = bool(datos[0][4][0][0])
        elif experto != bool(datos[0][4][0][0]):
            print(f"EXPERTO DISTINO PARA MISMO USUARIO {experto} != {bool(datos[0][4][0][0])}. Usuario {voluntario}")
            experto = True
    
    stats_ugr[voluntario] = {}            
    stats_ugr[voluntario]["nombre"] = nombre
    stats_ugr[voluntario]["apellidos"] = apellidos
    stats_ugr[voluntario]["edad"] = edad
    stats_ugr[voluntario]["genero"] = genero
    stats_ugr[voluntario]["experto"] = experto
    stats_ugr[voluntario]["data_files"] = ficheros
    stats_ugr[voluntario]["universidad"] = "UGR"
        
stats_ugr
# Out:
# EDAD DISTINTA PARA MISMO USUARIO 42 != 43. Usuario voluntario_ugr_12-_12
# EDAD DISTINTA PARA MISMO USUARIO 18 != 19. Usuario voluntario_ugr_17-_17
# EDAD DISTINTA PARA MISMO USUARIO 22 != 1. Usuario voluntario_ugr_19-_19
# EXPERTO DISTINO PARA MISMO USUARIO True != False. Usuario voluntario_ugr_25-_25
# EDAD DISTINTA PARA MISMO USUARIO 50 != 49. Usuario voluntario_ugr_35-_35
# {'voluntario_ugr_1-_1': {'nombre': 'voluntario_ugr_1',
#   'apellidos': '_1         ',
#   'edad': 23,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220401T131441.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_2-_2': {'nombre': 'voluntario_ugr_2',
#   'apellidos': '_2               ',
#   'edad': 24,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220317T113653.mat',
#    'ResultsJNDsNoiseFlatBG20220407T113228.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_3-_3': {'nombre': 'voluntario_ugr_3',
#   'apellidos': '_3           ',
#   'edad': 29,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220201T134054.mat',
#    'ResultsJNDsNoiseFlatBG20220202T124958.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_4-_4': {'nombre': 'voluntario_ugr_4',
#   'apellidos': '_4           ',
#   'edad': 43,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220427T114635.mat',
#    'ResultsJNDsNoiseFlatBG20220408T103353.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_5-_5': {'nombre': 'voluntario_ugr_5',
#   'apellidos': '_5               ',
#   'edad': 21,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220401T121203.mat',
#    'ResultsJNDsNoiseFlatBG20220323T132705.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_6-_6': {'nombre': 'voluntario_ugr_6',
#   'apellidos': '_6   ',
#   'edad': 29,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220303T125835.mat',
#    'ResultsJNDsNoiseFlatBG20220314T113216.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_7-_7': {'nombre': 'voluntario_ugr_7',
#   'apellidos': '_7     ',
#   'edad': 27,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220318T133520.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_8-_8': {'nombre': 'voluntario_ugr_8',
#   'apellidos': '_8            ',
#   'edad': 19,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220411T193944.mat',
#    'ResultsJNDsNoiseFlatBG20220420T172846.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_9-_9': {'nombre': 'voluntario_ugr_9',
#   'apellidos': '_9            ',
#   'edad': 29,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220223T112641.mat',
#    'ResultsJNDsNoiseFlatBG20220223T161544.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_10-_10': {'nombre': 'voluntario_ugr_10',
#   'apellidos': '_10           ',
#   'edad': 40,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220209T132743.mat',
#    'ResultsJNDsNoiseFlatBG20220204T134543.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_11-_11': {'nombre': 'voluntario_ugr_11',
#   'apellidos': '_11             ',
#   'edad': 27,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220202T113037.mat',
#    'ResultsJNDsNoiseFlatBG20220208T122326.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_12-_12': {'nombre': 'voluntario_ugr_12',
#   'apellidos': '_12          ',
#   'edad': 43,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220204T112945.mat',
#    'ResultsJNDsNoiseFlatBG20220426T124527.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_13-_13': {'nombre': 'voluntario_ugr_13',
#   'apellidos': '_13          ',
#   'edad': 44,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220121T133331.mat',
#    'ResultsJNDsNoiseFlatBG20220204T123031.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_14-_14': {'nombre': 'voluntario_ugr_14',
#   'apellidos': '_14          ',
#   'edad': 47,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220114T110151.mat',
#    'ResultsJNDsNoiseFlatBG20220121T104058.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_15-_15': {'nombre': 'voluntario_ugr_15',
#   'apellidos': '_15           ',
#   'edad': 23,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220406T123850.mat',
#    'ResultsJNDsNoiseFlatBG20220421T122349.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_16-_16': {'nombre': 'voluntario_ugr_16',
#   'apellidos': '_16     ',
#   'edad': 32,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20211217T115223.mat',
#    'ResultsJNDsNoiseFlatBG20220114T114049.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_17-_17': {'nombre': 'voluntario_ugr_17',
#   'apellidos': '_17              ',
#   'edad': 19,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220411T201459.mat',
#    'ResultsJNDsNoiseFlatBG20220421T180502.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_18-_18': {'nombre': 'voluntario_ugr_18',
#   'apellidos': '_18             ',
#   'edad': 50,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220422T111834.mat',
#    'ResultsJNDsNoiseFlatBG20220426T093703.mat',
#    'ResultsJNDsNoiseFlatBG20220405T100824.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_19-_19': {'nombre': 'voluntario_ugr_19',
#   'apellidos': '_19    ',
#   'edad': 22,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220331T123440.mat',
#    'ResultsJNDsNoiseFlatBG20220419T122341.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_20-_20': {'nombre': 'voluntario_ugr_20',
#   'apellidos': '_20   ',
#   'edad': 49,
#   'genero': 'M',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220302T112937.mat',
#    'ResultsJNDsNoiseFlatBG20220304T105123.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_21-_21': {'nombre': 'voluntario_ugr_21',
#   'apellidos': '_21            ',
#   'edad': 24,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220114T120209.mat',
#    'ResultsJNDsNoiseFlatBG20220128T092751.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_22-_22': {'nombre': 'voluntario_ugr_22',
#   'apellidos': '_22           ',
#   'edad': 21,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220328T140217.mat',
#    'ResultsJNDsNoiseFlatBG20220330T140514.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_23-_23': {'nombre': 'voluntario_ugr_23',
#   'apellidos': '_23             ',
#   'edad': 53,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220127T145837.mat',
#    'ResultsJNDsNoiseFlatBG20220121T122318.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_24-_24': {'nombre': 'voluntario_ugr_24',
#   'apellidos': '_24     ',
#   'edad': 37,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220202T174903.mat',
#    'ResultsJNDsNoiseFlatBG20220207T134041.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_25-_25': {'nombre': 'voluntario_ugr_25',
#   'apellidos': '_25          ',
#   'edad': 41,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220121T112811.mat',
#    'ResultsJNDsNoiseFlatBG20220127T141004.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_26-_26': {'nombre': 'voluntario_ugr_26',
#   'apellidos': '_26           ',
#   'edad': 22,
#   'genero': 'H',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220425T172713.mat',
#    'ResultsJNDsNoiseFlatBG20220422T124814.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_27-_27': {'nombre': 'voluntario_ugr_27',
#   'apellidos': '_27            ',
#   'edad': 30,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220201T111133.mat',
#    'ResultsJNDsNoiseFlatBG20220202T134220.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_28-_28': {'nombre': 'voluntario_ugr_28',
#   'apellidos': '_28          ',
#   'edad': 23,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220405T132104.mat',
#    'ResultsJNDsNoiseFlatBG20220401T134721.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_29-_29': {'nombre': 'voluntario_ugr_29',
#   'apellidos': '_29  ',
#   'edad': 60,
#   'genero': 'M',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220216T114246.mat',
#    'ResultsJNDsNoiseFlatBG20220223T104302.mat',
#    'ResultsJNDsNoiseFlatBG20220301T101810.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_30-_30': {'nombre': 'voluntario_ugr_30',
#   'apellidos': '_30           ',
#   'edad': 22,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220317T132259.mat',
#    'ResultsJNDsNoiseFlatBG20220407T125413.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_31-_31': {'nombre': 'voluntario_ugr_31',
#   'apellidos': '_31          ',
#   'edad': 18,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220420T175405.mat',
#    'ResultsJNDsNoiseFlatBG20220427T184121.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_32-_32': {'nombre': 'voluntario_ugr_32',
#   'apellidos': '_32       ',
#   'edad': 28,
#   'genero': 'H',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220114T124227.mat',
#    'ResultsJNDsNoiseFlatBG20220202T105219.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_33-_33': {'nombre': 'voluntario_ugr_33',
#   'apellidos': '_33             ',
#   'edad': 29,
#   'genero': 'M',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220211T125927.mat',
#    'ResultsJNDsNoiseFlatBG20220405T122450.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_34-_34': {'nombre': 'voluntario_ugr_34',
#   'apellidos': '_34   ',
#   'edad': 26,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220114T122007.mat',
#    'ResultsJNDsNoiseFlatBG20220128T130104.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_35-_35': {'nombre': 'voluntario_ugr_35',
#   'apellidos': '_35   ',
#   'edad': 50,
#   'genero': 'M',
#   'experto': True,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220308T111929.mat',
#    'ResultsJNDsNoiseFlatBG20220209T104348.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_36-_36': {'nombre': 'voluntario_ugr_36',
#   'apellidos': '_36  ',
#   'edad': 49,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220428T132532.mat'],
#   'universidad': 'UGR'},
#  'voluntario_ugr_37-_37': {'nombre': 'voluntario_ugr_37',
#   'apellidos': '_37             ',
#   'edad': 23,
#   'genero': 'M',
#   'experto': False,
#   'data_files': ['ResultsJNDsNoiseFlatBG20220407T102908.mat',
#    'ResultsJNDsNoiseFlatBG20220317T095724.mat'],
#   'universidad': 'UGR'}}

# %%
edades = [datos['edad'] for datos in stats_ugr.values()]
plt.hist(edades, bins=10, edgecolor='black')
plt.title('Histograma de Edades para UGR')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()


generos = [datos['genero'] for datos in stats_ugr.values()]
plt.hist(generos, bins=2, edgecolor='black')
plt.title('Histograma de Género para UGR')
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()


expertos = np.array([datos['experto'] for datos in stats_ugr.values()], dtype=np.uint8)
plt.hist(expertos, bins=2, edgecolor='black')
plt.title('Histograma de Experto para UGR')
plt.xlabel('Experto')
plt.ylabel('Frecuencia')
plt.xticks([0, 1], ['No', 'Sí'])
plt.show()

# %%
general_stats = {**stats_upv, **stats_ugr}

# Exportar a un diccionario
with open(PATH_VARIABLES+"/voluntarios.pkl", 'wb') as archivo:
    pickle.dump(general_stats, archivo)

edades = [datos['edad'] for datos in general_stats.values()]
plt.hist(edades, bins=10, edgecolor='black')
plt.title('Histograma de Edades general')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()


generos = [datos['genero'] for datos in general_stats.values()]
plt.hist(generos, bins=2, edgecolor='black')
plt.title('Histograma de Género general')
plt.xlabel('Género')
plt.ylabel('Frecuencia')
plt.show()


expertos = np.array([datos['experto'] for datos in general_stats.values()], dtype=np.uint8)
plt.hist(expertos, bins=2, edgecolor='black')
plt.title('Histograma de Experto general')
plt.xlabel('Experto')
plt.ylabel('Frecuencia')
plt.xticks([0, 1], ['No', 'Sí'])
plt.show()

contador = {'experto_H': 0, 'no_experto_H': 0, 'experto_M': 0, 'no_experto_M': 0}

for persona in general_stats.values():
    genero = persona['genero']
    experto = persona['experto']

    key = f"{'' if experto else 'no_'}experto_{genero}"
    contador[key] += 1

generos = ['H', 'M']
experto_counts = [contador['experto_H'], contador['experto_M']]
no_experto_counts = [contador['no_experto_H'], contador['no_experto_M']]

plt.bar(generos, experto_counts, label='experto')
plt.bar(generos, no_experto_counts, bottom=experto_counts, label='no experto')

plt.xlabel('Género')
plt.ylabel('Participantes')
plt.title('Histograma de participantes por Género y Experiencia')
plt.legend()
plt.show()

edades = {'H': [], 'M': []}
edades_xp = {True: [], False: []}

for persona in general_stats.values():
    genero = persona['genero']
    edad = persona['edad']
    experto = persona['experto']
    
    edades[genero].append(edad)
    edades_xp[experto].append(edad)

bins = np.linspace(0, max(max(edades['H']), max(edades['M'])), 10)
plt.hist([edades['H'], edades['M']], bins, color=['blue', 'red'], label=['Hombres', 'Mujeres'], edgecolor='black', stacked=True)

plt.xlim(11, None)
plt.xlabel('Edad')
plt.ylabel('Participantes')
plt.title('Histograma de participantes por Edad y Género')
plt.legend()

plt.show()


bins = np.linspace(0, max(max(edades_xp[True]), max(edades_xp[False])), 10)
plt.hist([edades_xp[True], edades_xp[False]], bins, label=['experto', 'no experto'], edgecolor='black', stacked=True)

plt.xlim(11, None)
plt.xlabel('Edad')
plt.ylabel('Participantes')
plt.title('Histograma de participantes por Edad y Experiencia')
plt.legend()

plt.show()

# %%
from scipy import stats

# Obtener las edades de los voluntarios
edades = [datos['edad'] for datos in general_stats.values()]

# Calcular la media
media_edades = np.mean(edades)

# Calcular la moda
moda_edades = stats.mode(edades).mode[0]

# Calcular la desviación estándar
std_edades = np.std(edades)

# Realizar prueba de normalidad (Shapiro-Wilk test)
shapiro_edades, p_value_edades = stats.shapiro(edades)

print("Media de las edades:", media_edades)
print("Moda de las edades:", moda_edades)
print("Desviación estándar de las edades:", std_edades)
print("Resultado del test de normalidad (Shapiro-Wilk) para las edades:")
print("Estadístico de prueba:", shapiro_edades)
print("Valor p:", p_value_edades)
print()

# Obtener los valores de género de los voluntarios
generos = [0 if datos['genero'] == 'M' else 1 for datos in general_stats.values()]

# Calcular la proporción de géneros
prop_generos = np.mean(generos)

# Realizar prueba de normalidad (Chi-square test)
chi2_generos, p_value_generos = stats.normaltest(generos)

print("Proporción de géneros:", prop_generos)
print("Resultado del test de normalidad (Chi-square) para la variable género:")
print("Estadístico de prueba:", chi2_generos)
print("Valor p:", p_value_generos)
print()


# Obtener los valores de experto de los voluntarios
expertos = [datos['experto'] for datos in general_stats.values()]

# Calcular la proporción de expertos
prop_expertos = np.mean(expertos)

# Realizar prueba de normalidad (Chi-square test)
chi2_expertos, p_value_expertos = stats.normaltest(expertos)

print("Proporción de expertos:", prop_expertos)
print("Resultado del test de normalidad (Chi-square) para la variable experto:")
print("Estadístico de prueba:", chi2_expertos)
print("Valor p:", p_value_expertos)



# Posible agrupación de edades:

p33 = np.percentile(edades, 33)
p66 = np.percentile(edades, 66)

# Dividir las edades en tres grupos
grupo1 = [edad for edad in edades if edad <= 23]
grupo2 = [edad for edad in edades if 23 < edad <= 40]
grupo3 = [edad for edad in edades if edad > 40]
print()
print(f"Edades: {edades}")
print(f"Grupo 1 (Edad <= {p33}): {grupo1}")
print(f"Grupo 2 ({p33} < edad <= {p66}): {grupo2}")
print(f"Grupo 3 (Edad > {p66}): {grupo3}")
# Out:
# Media de las edades: 34.044117647058826
# Moda de las edades: 21
# Desviación estándar de las edades: 13.21366697059104
# Resultado del test de normalidad (Shapiro-Wilk) para las edades:
# Estadístico de prueba: 0.9046897888183594
# Valor p: 7.529235153924674e-05
#
# Proporción de géneros: 0.5147058823529411
# Resultado del test de normalidad (Chi-square) para la variable género:
# Estadístico de prueba: 784.5960239950031
# Valor p: 4.23777727621232e-171
#
# Proporción de expertos: 0.20588235294117646
# Resultado del test de normalidad (Chi-square) para la variable experto:
# Estadístico de prueba: 18.159551875964286
# Valor p: 0.00011394713582189214
#
# Edades: [31, 60, 49, 63, 35, 45, 57, 41, 57, 34, 51, 51, 21, 37, 57, 31, 38, 21, 41, 21, 22, 21, 27, 41, 18, 19, 19, 19, 20, 54, 18, 23, 24, 29, 43, 21, 29, 27, 19, 29, 40, 27, 43, 44, 47, 23, 32, 19, 50, 22, 49, 24, 21, 53, 37, 41, 22, 30, 23, 60, 22, 18, 28, 29, 26, 50, 49, 23]
# Grupo 1 (Edad <= 23.11): [21, 21, 21, 22, 21, 18, 19, 19, 19, 20, 18, 23, 21, 19, 23, 19, 22, 21, 22, 23, 22, 18, 23]
# Grupo 2 (23.11 < edad <= 41.0): [31, 35, 34, 37, 31, 38, 27, 24, 29, 29, 27, 29, 40, 27, 32, 24, 37, 30, 28, 29, 26]
# Grupo 3 (Edad > 41.0): [60, 49, 63, 45, 57, 41, 57, 51, 51, 57, 41, 41, 54, 43, 43, 44, 47, 50, 49, 53, 41, 60, 50, 49]
# C:\Users\Luismi\AppData\Local\Temp\ipykernel_24180\3006620497.py:10: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   moda_edades = stats.mode(edades).mode[0]
